# %%
import sklearn.linear_model as skl_lm
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import plot_confusion_matrix
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn import preprocessing
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import ConfusionMatrixDisplay

import statsmodels.api as sm
import statsmodels.formula.api as smf

import pandas as pd
import numpy as np

df=pd.read_csv("European_bank_marketing.csv")

df.drop('duration', axis=1, inplace=True)
df.drop(columns = df.columns[df.nunique() == 1], inplace = True)
df[df.duplicated()]
df.drop_duplicates(inplace = True)

# Import LabelEncoder
from sklearn import preprocessing
#creating labelEncoder
le = preprocessing.LabelEncoder()
# Converting string labels into numbers.
string_cols = ['job', 'marital','education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
for col in string_cols:
    df[col] = le.fit_transform(df[col])
    
    
y = df.term_deposit
X = df.drop('term_deposit', axis=1).astype('float64')

# Standardise the data 
from sklearn.preprocessing import StandardScaler

X_scaled = StandardScaler().fit_transform(X) # normalizing the features

# Part A
Y = df['term_deposit']
X = df.drop('term_deposit',axis=1)
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0)

# 10%

def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.10).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
          pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.95','0.27','Nan'],
     'Recall':['0.73','0.74','Nan'],
     'F-score':['0.82','0.39','Nan'],
     'Accuracy':['Nan','Nan','0.73']}
a = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
a


# 20%
def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.20).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
          pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.94','0.41','Nan'],
     'Recall':['0.89','0.60','Nan'],
     'F-score':['0.91','0.49','Nan'],
     'Accuracy':['Nan','Nan','0.85']}
b = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
b

# 35% 
def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.35).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
         pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.91','0.58','Nan'],
     'Recall':['0.97','0.32','Nan'],
     'F-score':['0.94','0.41','Nan'],
     'Accuracy':['Nan','Nan','0.89']}
c = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
c

# 50%
def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.50).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
         pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression

lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.90','0.71','Nan'],
     'Recall':['0.99','0.2','Nan'],
     'F-score':['0.94','0.34','Nan'],
     'Accuracy':['Nan','Nan','0.90']}
d = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
d


# Part B 

x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0,test_size=0.3)

#10% 
def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.10).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
          pd.DataFrame(confusion_matrix(y_test, preds_proba)))
    
#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.95','0.26','Nan'],
     'Recall':['0.73','0.72','Nan'],
     'F-score':['0.83','0.39','Nan'],
     'Accuracy':['Nan','Nan','0.73']}
e = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
e

#20%


def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.20).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
          pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.93','0.45','Nan'],
     'Recall':['0.92','0.51','Nan'],
     'F-score':['0.93','0.48','Nan'],
     'Accuracy':['Nan','Nan','0.87']}
f = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
f

# 35%
def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.35).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
          pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.91','0.57','Nan'],
     'Recall':['0.97','0.29','Nan'],
     'F-score':['0.94','0.38','Nan'],
     'Accuracy':['Nan','Nan','0.89']}
g = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
g

#50 %

def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1]>=0.50).astype(int)
    print('                   ', name, '\n',
          classification_report(y_test, preds_proba),
          pd.DataFrame(confusion_matrix(y_test, preds_proba)))

#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

data={'Precision':['0.90','0.71','Nan'],
     'Recall':['0.99','0.20','Nan'],
     'F-score':['0.94','0.31','Nan'],
     'Accuracy':['Nan','Nan','0.90']}
h = pd.DataFrame(data, index =['No',
                               'Yes',
                                'Accuracy'])
h

# Part C

def model_assess(model, name='Sub'):
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    preds_proba = (model.predict_proba(x_test)[:,1])
    print('                   ', name, '\n',
          classification_report(y_test, model.predict(x_test)))

    
#Logistic Regression
lg = LogisticRegression(random_state=0)
model_assess(lg, 'Logistic Regression')

fig = plt.figure(figsize=(14,10))
plt.plot([0, 1], [0, 1],'r--')
#Logistic Regression
preds_proba_lg = (lg.predict_proba(x_test))
probslg = (preds_proba_lg[:, 1])
fpr, tpr, thresh = metrics.roc_curve(y_test, probslg)
auclg = roc_auc_score(y_test, probslg)
plt.plot(fpr, tpr, label=f'Logistic Regression, AUC = {str(round(auclg,3))}')
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.title("ROC curve")
plt.rcParams['axes.titlesize'] = 18
plt.legend()
plt.show()
# Out:
#                     Logistic Regression
#                precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      8698
#            1       0.27      0.74      0.39      1173
#
#     accuracy                           0.73      9871
#    macro avg       0.61      0.73      0.61      9871
# weighted avg       0.87      0.73      0.77      9871
#        0     1
# 0  6298  2400
# 1   306   867
#                     Logistic Regression
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      8698
#            1       0.41      0.60      0.49      1173
#
#     accuracy                           0.85      9871
#    macro avg       0.68      0.74      0.70      9871
# weighted avg       0.88      0.85      0.86      9871
#        0     1
# 0  7698  1000
# 1   473   700
#                     Logistic Regression
#                precision    recall  f1-score   support
#
# ...
